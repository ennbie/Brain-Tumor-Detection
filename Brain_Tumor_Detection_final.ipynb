# %% [markdown]
# <a href="https://colab.research.google.com/github/ennbie/Brain-Tumor-Detection/blob/main/Brain_Tumor_Detection_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Brain Tumor Detection using brain MRI images

# %% [markdown]
# Dataset obtained from : [Brain MRI Images for Brain Tumor Detection](https://www.kaggle.com/datasets/navoneel/brain-mri-images-for-brain-tumor-detection)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
DIRECTORY = "./drive/MyDrive/Brain tumor detection/"
DATA_PATH = DIRECTORY + "brain_tumor_dataset/"

# %% [markdown]
# ## Importing packages

# %%
import os
import shutil
import random
import math
import cv2
import numpy as np
import glob
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow import keras
from tensorflow.keras.layers import Dense, Flatten, Dropout
from sklearn.metrics import confusion_matrix, accuracy_score, roc_curve
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## Splitting Dataset into Training, Testing and Validation sets

# %%
SEED = 123
train = DIRECTORY + "train/"
test = DIRECTORY + "test/"
validation = DIRECTORY + "validation/"

# %%
for path in [train,test,validation]:
  os.makedirs(path + "yes/")
  os.makedirs(path + "no/")

# %%
test_examples = train_examples = validation_examples = 0

# %%
for yes_no in os.listdir(DATA_PATH):
      n = len(os.listdir(DATA_PATH + yes_no))
      for (i, file_name) in enumerate(os.listdir(DATA_PATH + yes_no)):
          img = DATA_PATH + yes_no + '/' + file_name
          if i < 10:
              shutil.copy(img, test + yes_no + '/' + file_name)
              test_examples += 1
          elif i < 0.85*n:
              shutil.copy(img, train + yes_no + '/' + file_name)
              train_examples += 1
          else:
              shutil.copy(img, validation + yes_no + '/' + file_name)
              validation_examples += 1

# %%
print(f"Number of training examples: {train_examples}")
print(f"Number of test examples: {test_examples}")
print(f"Number of validation examples: {validation_examples}")
# Out:
# Number of training examples: 196
# Number of test examples: 20
# Number of validation examples: 37

# %% [markdown]
# ## Image Loading and Preprocessing

# %%
def load_data(path):
  X=[]
  Y=[]
  for img_file in glob.iglob(path+"yes/*"):
      img = cv2.imread(img_file)
      img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
      img = cv2.resize(img, (224, 224))
      X.append(img)
      Y.append(1)

  for img_file in glob.iglob(path+"no/*"):
      img = cv2.imread(img_file)
      img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
      img = cv2.resize(img, (224, 224))
      X.append(img)
      Y.append(0)

  return np.array(X), np.array(Y)

X_train, Y_train = load_data(train)
X_test, Y_test = load_data(test)
X_val, Y_val = load_data(validation)

# %% [markdown]
# ## Visualizing Brain MRI Images

# %% [markdown]
# 1. Plot random images from dataset

# %%
index = np.random.choice(X_train.shape[0], 5, replace=False)
plt.figure(figsize=(10,10))

for i in range(5):
    plt.subplot(1, 5, i+1)
    plt.imshow(X_train[index[i]])
    plt.title("Tumor" if Y_train[index[i]] else "Healthy")

plt.tight_layout()
plt.show()

# %% [markdown]
# 2. Plot examples of images with tumor and without tumor

# %%
# Define the labels and their corresponding colors
labels = {0: 'Healthy', 1: 'Tumor'}
colors = {0: 'blue', 1: 'red'}

# Plot some images from the train set for each label
fig, axs = plt.subplots(2, 3, figsize=(6, 5))
for i, label in enumerate([0, 1]):
    images = [x for x, y in zip(X_train, Y_train) if y == label][:3]
    for j,img in enumerate(images):
        axs[i, j].imshow(img)
        axs[i, j].set_title(labels[label], color=colors[label])
plt.show()

# %% [markdown]
# ## Data Augmentation

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=50,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    brightness_range=[0.8, 1.2],
    horizontal_flip=True,
    vertical_flip=True,
    preprocessing_function=preprocess_input
)

test_datagen = ImageDataGenerator(rescale=1./255,
    preprocessing_function=preprocess_input)

train_generator = train_datagen.flow(
    X_train,
    Y_train,
    batch_size=32,
    shuffle=True,
    seed=SEED
)

val_generator = test_datagen.flow(
    X_val,
    Y_val,
    batch_size=16,
    shuffle=True,
    seed=SEED
)

test_generator = test_datagen.flow(
    X_test,
    Y_test,
    batch_size=16,
    shuffle=False,
    seed=SEED
)

# %% [markdown]
# ## Constructing Model using Transfer Learning on VGG16

# %%
base_model = VGG16(weights="imagenet",
                   include_top=False,
                   input_shape=(224,224,3))
base_model.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model = Sequential([
    base_model,
    Flatten(name='flatten'),
    Dropout(0.3),
    Dense(1, activation="sigmoid")
])
# model.layers[0].trainable = False

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 7, 7, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │        25,089 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,739,777 (56.23 MB)
#  Trainable params: 14,739,777 (56.23 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# !pip install keras-nightly

# %%
model.compile(loss = tf.keras.losses.BinaryCrossentropy(), optimizer = Adam(learning_rate=0.0001), metrics=["accuracy"])

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
checkpoint = ModelCheckpoint("effnet.keras",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.7, patience = 3, min_delta = 0.001,
                              mode='auto',verbose=1)

# %%
history = model.fit(train_generator, epochs=40, batch_size=32, validation_data=val_generator, callbacks=[checkpoint,reduce_lr])
# Out:
# Epoch 1/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5766 - loss: 0.7189
# Epoch 1: val_accuracy improved from None to 0.81081, saving model to effnet.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 73s 5s/step - accuracy: 0.5969 - loss: 0.6861 - val_accuracy: 0.8108 - val_loss: 0.5795 - learning_rate: 1.0000e-04
# Epoch 2/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 700ms/step - accuracy: 0.5844 - loss: 0.6445
# Epoch 2: val_accuracy did not improve from 0.81081
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 745ms/step - accuracy: 0.6480 - loss: 0.6395 - val_accuracy: 0.7838 - val_loss: 0.4775 - learning_rate: 1.0000e-04
# Epoch 3/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step - accuracy: 0.6460 - loss: 0.5977
# Epoch 3: val_accuracy did not improve from 0.81081
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 523ms/step - accuracy: 0.6888 - loss: 0.5870 - val_accuracy: 0.7838 - val_loss: 0.5043 - learning_rate: 1.0000e-04
# Epoch 4/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 0.6584 - loss: 0.6224
# Epoch 4: val_accuracy did not improve from 0.81081
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 6.999999823165126e-05.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 545ms/step - accuracy: 0.6429 - loss: 0.6310 - val_accuracy: 0.7838 - val_loss: 0.4718 - learning_rate: 1.0000e-04
# Epoch 5/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 670ms/step - accuracy: 0.6120 - loss: 0.5802
# Epoch 5: val_accuracy did not improve from 0.81081
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 721ms/step - accuracy: 0.6735 - loss: 0.5619 - val_accuracy: 0.7838 - val_loss: 0.4140 - learning_rate: 7.0000e-05
# Epoch 6/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 552ms/step - accuracy: 0.7207 - loss: 0.5437
# Epoch 6: val_accuracy did not improve from 0.81081
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 596ms/step - accuracy: 0.7602 - loss: 0.5103 - val_accuracy: 0.7838 - val_loss: 0.4164 - learning_rate: 7.0000e-05
# Epoch 7/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.7862 - loss: 0.4879
# Epoch 7: val_accuracy did not improve from 0.81081
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 4.899999621557071e-05.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 527ms/step - accuracy: 0.7602 - loss: 0.5596 - val_accuracy: 0.7838 - val_loss: 0.3754 - learning_rate: 7.0000e-05
# Epoch 8/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - accuracy: 0.7240 - loss: 0.5680
# Epoch 8: val_accuracy did not improve from 0.81081
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 593ms/step - accuracy: 0.7245 - loss: 0.5554 - val_accuracy: 0.8108 - val_loss: 0.4314 - learning_rate: 4.9000e-05
# Epoch 9/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 597ms/step - accuracy: 0.7306 - loss: 0.5367
# Epoch 9: val_accuracy improved from 0.81081 to 0.83784, saving model to effnet.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 752ms/step - accuracy: 0.6684 - loss: 0.5961 - val_accuracy: 0.8378 - val_loss: 0.3953 - learning_rate: 4.9000e-05
# Epoch 10/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - accuracy: 0.7265 - loss: 0.5223
# Epoch 10: val_accuracy did not improve from 0.83784
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 530ms/step - accuracy: 0.7041 - loss: 0.5486 - val_accuracy: 0.8378 - val_loss: 0.3330 - learning_rate: 4.9000e-05
# Epoch 11/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 563ms/step - accuracy: 0.7744 - loss: 0.4991
# Epoch 11: val_accuracy improved from 0.83784 to 0.89189, saving model to effnet.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 719ms/step - accuracy: 0.7908 - loss: 0.4802 - val_accuracy: 0.8919 - val_loss: 0.2869 - learning_rate: 4.9000e-05
# Epoch 12/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - accuracy: 0.7614 - loss: 0.4785
# Epoch 12: val_accuracy did not improve from 0.89189
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 528ms/step - accuracy: 0.7653 - loss: 0.4701 - val_accuracy: 0.8919 - val_loss: 0.2776 - learning_rate: 4.9000e-05
# Epoch 13/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.8009 - loss: 0.4284
# Epoch 13: val_accuracy did not improve from 0.89189
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 524ms/step - accuracy: 0.7959 - loss: 0.4371 - val_accuracy: 0.8919 - val_loss: 0.2451 - learning_rate: 4.9000e-05
# Epoch 14/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 599ms/step - accuracy: 0.7975 - loss: 0.4406
# Epoch 14: val_accuracy did not improve from 0.89189
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 3.4299996332265434e-05.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 649ms/step - accuracy: 0.8010 - loss: 0.4129 - val_accuracy: 0.8919 - val_loss: 0.2303 - learning_rate: 4.9000e-05
# Epoch 15/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step - accuracy: 0.8467 - loss: 0.4033
# Epoch 15: val_accuracy did not improve from 0.89189
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 524ms/step - accuracy: 0.8520 - loss: 0.3801 - val_accuracy: 0.8649 - val_loss: 0.2934 - learning_rate: 3.4300e-05
# Epoch 16/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step - accuracy: 0.7817 - loss: 0.4227
# Epoch 16: val_accuracy did not improve from 0.89189
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 532ms/step - accuracy: 0.8061 - loss: 0.4030 - val_accuracy: 0.8108 - val_loss: 0.3986 - learning_rate: 3.4300e-05
# Epoch 17/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - accuracy: 0.8343 - loss: 0.3446
# Epoch 17: val_accuracy did not improve from 0.89189
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 2.400999692326877e-05.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 589ms/step - accuracy: 0.8112 - loss: 0.3646 - val_accuracy: 0.8919 - val_loss: 0.2474 - learning_rate: 3.4300e-05
# Epoch 18/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - accuracy: 0.8256 - loss: 0.3957
# Epoch 18: val_accuracy did not improve from 0.89189
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 530ms/step - accuracy: 0.8571 - loss: 0.3386 - val_accuracy: 0.8378 - val_loss: 0.3550 - learning_rate: 2.4010e-05
# Epoch 19/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.8403 - loss: 0.3754
# Epoch 19: val_accuracy improved from 0.89189 to 0.91892, saving model to effnet.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 676ms/step - accuracy: 0.8265 - loss: 0.3941 - val_accuracy: 0.9189 - val_loss: 0.2230 - learning_rate: 2.4010e-05
# Epoch 20/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - accuracy: 0.8071 - loss: 0.3512
# Epoch 20: val_accuracy did not improve from 0.91892
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 590ms/step - accuracy: 0.8265 - loss: 0.3393 - val_accuracy: 0.9189 - val_loss: 0.2249 - learning_rate: 2.4010e-05
# Epoch 21/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - accuracy: 0.8822 - loss: 0.3342
# Epoch 21: val_accuracy did not improve from 0.91892
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 528ms/step - accuracy: 0.8724 - loss: 0.3234 - val_accuracy: 0.9189 - val_loss: 0.2188 - learning_rate: 2.4010e-05
# Epoch 22/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.8952 - loss: 0.2465
# Epoch 22: val_accuracy did not improve from 0.91892
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.6806997336971108e-05.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 562ms/step - accuracy: 0.8929 - loss: 0.2782 - val_accuracy: 0.9189 - val_loss: 0.2082 - learning_rate: 2.4010e-05
# Epoch 23/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - accuracy: 0.9274 - loss: 0.2969
# Epoch 23: val_accuracy improved from 0.91892 to 0.94595, saving model to effnet.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 688ms/step - accuracy: 0.9082 - loss: 0.2767 - val_accuracy: 0.9459 - val_loss: 0.1942 - learning_rate: 1.6807e-05
# Epoch 24/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step - accuracy: 0.8943 - loss: 0.2835
# Epoch 24: val_accuracy did not improve from 0.94595
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 530ms/step - accuracy: 0.9031 - loss: 0.2677 - val_accuracy: 0.9189 - val_loss: 0.1829 - learning_rate: 1.6807e-05
# Epoch 25/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - accuracy: 0.8957 - loss: 0.2848
# Epoch 25: val_accuracy did not improve from 0.94595
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 530ms/step - accuracy: 0.8878 - loss: 0.2744 - val_accuracy: 0.9189 - val_loss: 0.2497 - learning_rate: 1.6807e-05
# Epoch 26/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - accuracy: 0.9010 - loss: 0.2403
# Epoch 26: val_accuracy did not improve from 0.94595
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.1764897499233484e-05.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 572ms/step - accuracy: 0.8980 - loss: 0.2466 - val_accuracy: 0.8919 - val_loss: 0.2316 - learning_rate: 1.6807e-05
# Epoch 27/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - accuracy: 0.8530 - loss: 0.3294
# Epoch 27: val_accuracy did not improve from 0.94595
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 545ms/step - accuracy: 0.8827 - loss: 0.2555 - val_accuracy: 0.8919 - val_loss: 0.2104 - learning_rate: 1.1765e-05
# Epoch 28/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - accuracy: 0.9121 - loss: 0.2046
# Epoch 28: val_accuracy did not improve from 0.94595
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 530ms/step - accuracy: 0.9235 - loss: 0.2041 - val_accuracy: 0.8919 - val_loss: 0.2478 - learning_rate: 1.1765e-05
# Epoch 29/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.9120 - loss: 0.2266
# Epoch 29: val_accuracy did not improve from 0.94595
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 8.235428504121954e-06.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 561ms/step - accuracy: 0.9031 - loss: 0.2314 - val_accuracy: 0.9189 - val_loss: 0.2011 - learning_rate: 1.1765e-05
# Epoch 30/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - accuracy: 0.8654 - loss: 0.2958
# Epoch 30: val_accuracy did not improve from 0.94595
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 567ms/step - accuracy: 0.8827 - loss: 0.2580 - val_accuracy: 0.9189 - val_loss: 0.2361 - learning_rate: 8.2354e-06
# Epoch 31/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - accuracy: 0.9303 - loss: 0.1858
# Epoch 31: val_accuracy did not improve from 0.94595
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 527ms/step - accuracy: 0.9286 - loss: 0.1837 - val_accuracy: 0.8919 - val_loss: 0.1866 - learning_rate: 8.2354e-06
# Epoch 32/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 589ms/step - accuracy: 0.9403 - loss: 0.1605
# Epoch 32: val_accuracy did not improve from 0.94595
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 5.764799698226852e-06.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 638ms/step - accuracy: 0.9286 - loss: 0.1820 - val_accuracy: 0.9189 - val_loss: 0.1985 - learning_rate: 8.2354e-06
# Epoch 33/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - accuracy: 0.9295 - loss: 0.1603
# Epoch 33: val_accuracy did not improve from 0.94595
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 635ms/step - accuracy: 0.9184 - loss: 0.1776 - val_accuracy: 0.9189 - val_loss: 0.2388 - learning_rate: 5.7648e-06
# Epoch 34/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 522ms/step - accuracy: 0.9286 - loss: 0.1899
# Epoch 34: val_accuracy did not improve from 0.94595
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 566ms/step - accuracy: 0.9031 - loss: 0.2268 - val_accuracy: 0.9189 - val_loss: 0.2116 - learning_rate: 5.7648e-06
# Epoch 35/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - accuracy: 0.9277 - loss: 0.1936
# Epoch 35: val_accuracy did not improve from 0.94595
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 4.035359916088054e-06.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 535ms/step - accuracy: 0.9439 - loss: 0.1868 - val_accuracy: 0.9189 - val_loss: 0.1809 - learning_rate: 5.7648e-06
# Epoch 36/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - accuracy: 0.8840 - loss: 0.2042
# Epoch 36: val_accuracy did not improve from 0.94595
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 585ms/step - accuracy: 0.8980 - loss: 0.1987 - val_accuracy: 0.9189 - val_loss: 0.1901 - learning_rate: 4.0354e-06
# Epoch 37/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - accuracy: 0.9313 - loss: 0.1785
# Epoch 37: val_accuracy did not improve from 0.94595
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 526ms/step - accuracy: 0.9184 - loss: 0.2018 - val_accuracy: 0.8919 - val_loss: 0.1733 - learning_rate: 4.0354e-06
# Epoch 38/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.9407 - loss: 0.1920
# Epoch 38: val_accuracy did not improve from 0.94595
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 2.8247518457646947e-06.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 540ms/step - accuracy: 0.9439 - loss: 0.1653 - val_accuracy: 0.9189 - val_loss: 0.1865 - learning_rate: 4.0354e-06
# Epoch 39/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - accuracy: 0.9519 - loss: 0.1248
# Epoch 39: val_accuracy did not improve from 0.94595
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 619ms/step - accuracy: 0.9388 - loss: 0.1521 - val_accuracy: 0.9189 - val_loss: 0.1960 - learning_rate: 2.8248e-06
# Epoch 40/40
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - accuracy: 0.9479 - loss: 0.1526
# Epoch 40: val_accuracy did not improve from 0.94595
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 528ms/step - accuracy: 0.9388 - loss: 0.1689 - val_accuracy: 0.9189 - val_loss: 0.1893 - learning_rate: 2.8248e-06

# %% [markdown]
# ## Plot model performance

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, len(history.epoch) + 1)

plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Set')
plt.plot(epochs_range, val_acc, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Set')
plt.plot(epochs_range, val_loss, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')

plt.tight_layout()
plt.show()

# %%
# Y_pred = tf.nn.sigmoid(model.predict(X_test))
Y_pred = model.predict(test_generator)
Y_pred = np.round(Y_pred).astype(int)

test_accuracy = accuracy_score(Y_test, Y_pred)
print('Test accuracy:', test_accuracy)

cm = confusion_matrix(Y_test, Y_pred)

sns.heatmap(cm, annot=True, cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 3s/step
# Test accuracy: 0.95

# %%
model.save("model.keras")

# %%
from tensorflow.keras.models import load_model

# Load the saved model
loaded_model = load_model("/content/effnet.keras")


# Make predictions on the test set
Y_pred_loaded = loaded_model.predict(test_generator)
Y_pred_loaded = np.round(Y_pred_loaded).astype(int)

# Evaluate the loaded model's performance
test_accuracy_loaded = accuracy_score(Y_test, Y_pred_loaded)
print('Test accuracy of loaded model:', test_accuracy_loaded)

cm_loaded = confusion_matrix(Y_test, Y_pred_loaded)

sns.heatmap(cm_loaded, annot=True, cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix (Loaded Model)')
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 929ms/step
# Test accuracy of loaded model: 0.95
